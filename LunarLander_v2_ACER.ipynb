# %% [markdown]
# <a href="https://colab.research.google.com/github/Lego514/practice-for-class/blob/main/LunarLander_v2_ACER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install linux server packages using apt-get and Python packages using pip
# !apt-get install swig cmake libopenmpi-dev zlib1g-dev xvfb x11-utils ffmpeg -qq #remove -qq for full output
# !pip install stable-baselines[mpi] box2d box2d-kengz pyvirtualdisplay pyglet==1.3.1 --quiet #remove --quiet for full output 
# Stable Baselines only supports tensorflow 1.x for now
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
#import dependencis required to run & train our model + record a video
import gym
import imageio
import numpy as np
import base64
import IPython
import PIL.Image
import pyvirtualdisplay

# Video stuff 
from pathlib import Path
from IPython import display as ipythondisplay

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import VecVideoRecorder, SubprocVecEnv, DummyVecEnv
from stable_baselines import ACER
from stable_baselines.bench import Monitor
from stable_baselines.results_plotter import load_results, ts2xy
from stable_baselines.ddpg import AdaptiveParamNoiseSpec
from stable_baselines import results_plotter
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# set enviorment variables that we will use in our code
env_id = 'LunarLander-v2'
video_folder = '/videos'
video_length = 500


# set our inital enviorment
env = DummyVecEnv([lambda: gym.make(env_id)]) 
obs = env.reset()

# %%
print('State shape: ', env.observation_space.shape)
print('Number of actions: ', env.action_space.n)
# Out:
# State shape:  (8,)
# Number of actions:  4

# %%
# Evaluation Function
def evaluate(model, num_steps=1000):
  """
  Evaluate a RL agent
  :param model: (BaseRLModel object) the RL Agent
  :param num_steps: (int) number of timesteps to evaluate it
  :return: (float) Mean reward for the last 100 episodes
  """
  episode_rewards = [0.0]
  obs = env.reset()
  for i in range(num_steps):
      # _states are only useful when using LSTM policies
      action, _states = model.predict(obs)

      obs, reward, done, info = env.step(action)
      
      # Stats
      episode_rewards[-1] += reward
      if done:
          obs = env.reset()
          episode_rewards.append(0.0)
  # Compute mean reward for the last 100 episodes
  mean_100ep_reward = round(np.mean(episode_rewards[-100:]), 1)
  print("Mean reward:", mean_100ep_reward, "Num episodes:", len(episode_rewards))
  
  return mean_100ep_reward

# %%
# Make video
# Set up fake display; otherwise rendering will fail on colab
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'

# %%
# Record video
def record_video(env_id, model, video_length=500, prefix='', video_folder='videos/'):
  """
  :param env_id: (str)
  :param model: (RL model)
  :param video_length: (int)
  :param prefix: (str)
  :param video_folder: (str)
  """
  eval_env = DummyVecEnv([lambda: gym.make('LunarLander-v2')])
  # Start the video at step=0 and record 500 steps
  eval_env = VecVideoRecorder(env, video_folder=video_folder,
                              record_video_trigger=lambda step: step == 0, video_length=video_length,
                              name_prefix=prefix)

  obs = eval_env.reset()
  for _ in range(video_length):
    action, _ = model.predict(obs)
    obs, _, _, _ = eval_env.step(action)

  # Close the video recorder
  eval_env.close()

# %%
# Display video
def show_videos(video_path='', prefix=''):
  html = []
  for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
      video_b64 = base64.b64encode(mp4.read_bytes())
      html.append('''<video alt="{}" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>'''.format(mp4, video_b64.decode('ascii')))
  ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
# Define the model
model = ACER(MlpPolicy, env, verbose=1)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/tf_util.py:85: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/tf_util.py:94: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/policies.py:50: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/input.py:26: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/policies.py:260: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/a2c/utils.py:145: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/distributions.py:319: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/distributions.py:320: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/a2c/utils.py:309: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/moving_averages.py:433: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/acer/acer_simple.py:318: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/acer/acer_simple.py:350: The name tf.global_norm is deprecated. Please use tf.linalg.global_norm instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/acer/acer_simple.py:362: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/acer/acer_simple.py:374: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/acer/acer_simple.py:399: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/acer/acer_simple.py:401: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
# Record & show video #0
record_video('LunarLander-v2', model, video_length=1000, prefix='ramdom')
show_videos('videos', prefix='ramdom')
mean_reward_before_train = evaluate(model, num_steps=1000)
# Out:
# Saving video to  /content/videos/ramdom-step-0-to-step-1000.mp4
# <video alt="videos/ramdom-step-0-to-step-1000.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
# Mean reward: -162.5 Num episodes: 12

# %%
# Define the model
model = ACER('MlpPolicy', env, verbose=1) # add & tweak default parameters, messure your output & improve link to parameters above (it will however work with default)

# %%
# Train model
model.learn(total_timesteps=50000)
# Save model
model.save("ACER-LunarLander-v2-50000")
# Out:
# -----------------------------------
# | avg_norm_adj        | 18.4      |
# | avg_norm_g          | 74.8      |
# | avg_norm_grads_f    | 64.8      |
# | avg_norm_k          | 2         |
# | avg_norm_k_dot_g    | 74.8      |
# | entropy             | 29.1      |
# | explained_variance  | -6.69e-05 |
# | fps                 | 0         |
# | loss                | 83        |
# | loss_bc             | -0        |
# | loss_f              | -25.9     |
# | loss_policy         | -25.9     |
# | loss_q              | 218       |
# | mean_episode_length | 0         |
# | mean_episode_reward | 0         |
# | norm_grads          | 23.1      |
# | norm_grads_policy   | 16.5      |
# | norm_grads_q        | 16.1      |
# | total_timesteps     | 0         |
# -----------------------------------
# ----------------------------------
# | avg_norm_adj        | 12.4     |
# | avg_norm_g          | 50.5     |
# | avg_norm_grads_f    | 43.7     |
# | avg_norm_k          | 2        |
# | avg_norm_k_dot_g    | 50.9     |
# | entropy             | 29.1     |
# | explained_variance  | 0.00705  |
# | fps                 | 488      |
# | loss                | 47.3     |
# | loss_bc             | -0       |
# | loss_f              | -17.4    |
# | loss_policy         | -17.4    |
# | loss_q              | 130      |
# | mean_episode_length | 106      |
# | mean_episode_reward | -199     |
# | norm_grads          | 13.1     |
# | norm_grads_policy   | 6.77     |
# | norm_grads_q        | 11.2     |
# | total_timesteps     | 2000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 24.2     |
# | avg_norm_g          | 97.4     |
# | avg_norm_grads_f    | 82.5     |
# | avg_norm_k          | 2.1      |
# | avg_norm_k_dot_g    | 107      |
# | entropy             | 27.3     |
# | explained_variance  | -0.00684 |
# | fps                 | 463      |
# | loss                | 126      |
# | loss_bc             | -0       |
# | loss_f              | -29.3    |
# | loss_policy         | -29.3    |
# | loss_q              | 310      |
# | mean_episode_length | 144      |
# | mean_episode_reward | -196     |
# | norm_grads          | 49.4     |
# | norm_grads_policy   | 15.1     |
# | norm_grads_q        | 47       |
# | total_timesteps     | 4000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 16.5     |
# | avg_norm_g          | 146      |
# | avg_norm_grads_f    | 138      |
# | avg_norm_k          | 2.67     |
# | avg_norm_k_dot_g    | 123      |
# | entropy             | 11.7     |
# | explained_variance  | -0.00128 |
# | fps                 | 471      |
# | loss                | 1.65e+03 |
# | loss_bc             | -0       |
# | loss_f              | -40.9    |
# | loss_policy         | -40.9    |
# | loss_q              | 3.38e+03 |
# | mean_episode_length | 154      |
# | mean_episode_reward | -264     |
# | norm_grads          | 218      |
# | norm_grads_policy   | 42       |
# | norm_grads_q        | 214      |
# | total_timesteps     | 6000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 18.2     |
# | avg_norm_g          | 81.2     |
# | avg_norm_grads_f    | 70.1     |
# | avg_norm_k          | 2.24     |
# | avg_norm_k_dot_g    | 88.4     |
# | entropy             | 22.7     |
# | explained_variance  | 0.157    |
# | fps                 | 478      |
# | loss                | 104      |
# | loss_bc             | -0       |
# | loss_f              | -21.7    |
# | loss_policy         | -21.7    |
# | loss_q              | 252      |
# | mean_episode_length | 170      |
# | mean_episode_reward | -320     |
# | norm_grads          | 53.8     |
# | norm_grads_policy   | 9.84     |
# | norm_grads_q        | 52.9     |
# | total_timesteps     | 8000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 42.3     |
# | avg_norm_grads_f    | 42.3     |
# | avg_norm_k          | 2.11     |
# | avg_norm_k_dot_g    | 51.5     |
# | entropy             | 15.5     |
# | explained_variance  | 0.181    |
# | fps                 | 480      |
# | loss                | 135      |
# | loss_bc             | -0       |
# | loss_f              | 14.3     |
# | loss_policy         | 14.3     |
# | loss_q              | 241      |
# | mean_episode_length | 163      |
# | mean_episode_reward | -342     |
# | norm_grads          | 78.4     |
# | norm_grads_policy   | 48.8     |
# | norm_grads_q        | 61.4     |
# | total_timesteps     | 10000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 83.2     |
# | avg_norm_grads_f    | 83.2     |
# | avg_norm_k          | 2.15     |
# | avg_norm_k_dot_g    | 88.2     |
# | entropy             | 15.1     |
# | explained_variance  | -0.00655 |
# | fps                 | 477      |
# | loss                | 516      |
# | loss_bc             | -0       |
# | loss_f              | 27.9     |
# | loss_policy         | 27.9     |
# | loss_q              | 977      |
# | mean_episode_length | 177      |
# | mean_episode_reward | -298     |
# | norm_grads          | 145      |
# | norm_grads_policy   | 85.2     |
# | norm_grads_q        | 117      |
# | total_timesteps     | 12000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 6.82     |
# | avg_norm_g          | 43.6     |
# | avg_norm_grads_f    | 39.9     |
# | avg_norm_k          | 2.48     |
# | avg_norm_k_dot_g    | 42.5     |
# | entropy             | 13.8     |
# | explained_variance  | 0.00471  |
# | fps                 | 472      |
# | loss                | 158      |
# | loss_bc             | -0       |
# | loss_f              | -12.5    |
# | loss_policy         | -12.5    |
# | loss_q              | 341      |
# | mean_episode_length | 182      |
# | mean_episode_reward | -218     |
# | norm_grads          | 58.4     |
# | norm_grads_policy   | 8.81     |
# | norm_grads_q        | 57.7     |
# | total_timesteps     | 14000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.00986  |
# | avg_norm_g          | 3.7      |
# | avg_norm_grads_f    | 3.68     |
# | avg_norm_k          | 3.12     |
# | avg_norm_k_dot_g    | 5.1      |
# | entropy             | 20.2     |
# | explained_variance  | 0.279    |
# | fps                 | 464      |
# | loss                | 1.4      |
# | loss_bc             | -0       |
# | loss_f              | 1        |
# | loss_policy         | 1        |
# | loss_q              | 1.2      |
# | mean_episode_length | 195      |
# | mean_episode_reward | -180     |
# | norm_grads          | 12.5     |
# | norm_grads_policy   | 1.88     |
# | norm_grads_q        | 12.4     |
# | total_timesteps     | 16000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 10.2     |
# | avg_norm_grads_f    | 10.2     |
# | avg_norm_k          | 2.45     |
# | avg_norm_k_dot_g    | 10.2     |
# | entropy             | 16.5     |
# | explained_variance  | -0.0876  |
# | fps                 | 460      |
# | loss                | 6.6      |
# | loss_bc             | -0       |
# | loss_f              | 2.69     |
# | loss_policy         | 2.69     |
# | loss_q              | 8.15     |
# | mean_episode_length | 231      |
# | mean_episode_reward | -138     |
# | norm_grads          | 10.3     |
# | norm_grads_policy   | 2.54     |
# | norm_grads_q        | 9.95     |
# | total_timesteps     | 18000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 2.36     |
# | avg_norm_g          | 13.8     |
# | avg_norm_grads_f    | 12.5     |
# | avg_norm_k          | 2.04     |
# | avg_norm_k_dot_g    | 14       |
# | entropy             | 19.1     |
# | explained_variance  | -0.00898 |
# | fps                 | 459      |
# | loss                | 13.2     |
# | loss_bc             | -0       |
# | loss_f              | -2.27    |
# | loss_policy         | -2.27    |
# | loss_q              | 31.4     |
# | mean_episode_length | 251      |
# | mean_episode_reward | -132     |
# | norm_grads          | 11.6     |
# | norm_grads_policy   | 9.15     |
# | norm_grads_q        | 7.11     |
# | total_timesteps     | 20000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.944    |
# | avg_norm_g          | 6.69     |
# | avg_norm_grads_f    | 6.17     |
# | avg_norm_k          | 2.19     |
# | avg_norm_k_dot_g    | 5.85     |
# | entropy             | 14.2     |
# | explained_variance  | 0.0814   |
# | fps                 | 459      |
# | loss                | 6.42     |
# | loss_bc             | -0       |
# | loss_f              | -1.85    |
# | loss_policy         | -1.85    |
# | loss_q              | 16.8     |
# | mean_episode_length | 260      |
# | mean_episode_reward | -125     |
# | norm_grads          | 20.1     |
# | norm_grads_policy   | 15.2     |
# | norm_grads_q        | 13.3     |
# | total_timesteps     | 22000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 17.4     |
# | avg_norm_grads_f    | 17.4     |
# | avg_norm_k          | 1.96     |
# | avg_norm_k_dot_g    | 17.1     |
# | entropy             | 8.7      |
# | explained_variance  | -0.104   |
# | fps                 | 452      |
# | loss                | 37.8     |
# | loss_bc             | -0       |
# | loss_f              | 5.26     |
# | loss_policy         | 5.26     |
# | loss_q              | 65.2     |
# | mean_episode_length | 281      |
# | mean_episode_reward | -124     |
# | norm_grads          | 118      |
# | norm_grads_policy   | 12.9     |
# | norm_grads_q        | 117      |
# | total_timesteps     | 24000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 59       |
# | avg_norm_grads_f    | 59       |
# | avg_norm_k          | 2.17     |
# | avg_norm_k_dot_g    | 59       |
# | entropy             | 1.3      |
# | explained_variance  | 0.23     |
# | fps                 | 446      |
# | loss                | 1.55e+03 |
# | loss_bc             | -0       |
# | loss_f              | 0.533    |
# | loss_policy         | 0.533    |
# | loss_q              | 3.1e+03  |
# | mean_episode_length | 308      |
# | mean_episode_reward | -101     |
# | norm_grads          | 1.27e+03 |
# | norm_grads_policy   | 4.9      |
# | norm_grads_q        | 1.27e+03 |
# | total_timesteps     | 26000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 10.1     |
# | avg_norm_g          | 35       |
# | avg_norm_grads_f    | 29.5     |
# | avg_norm_k          | 1.73     |
# | avg_norm_k_dot_g    | 29.9     |
# | entropy             | 20.4     |
# | explained_variance  | 0.926    |
# | fps                 | 444      |
# | loss                | 13       |
# | loss_bc             | -0       |
# | loss_f              | -7.86    |
# | loss_policy         | -7.86    |
# | loss_q              | 42.1     |
# | mean_episode_length | 314      |
# | mean_episode_reward | -76.5    |
# | norm_grads          | 236      |
# | norm_grads_policy   | 8.38     |
# | norm_grads_q        | 236      |
# | total_timesteps     | 28000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.00638  |
# | avg_norm_g          | 4.66     |
# | avg_norm_grads_f    | 4.65     |
# | avg_norm_k          | 2.08     |
# | avg_norm_k_dot_g    | 4.67     |
# | entropy             | 8.7      |
# | explained_variance  | 0.0312   |
# | fps                 | 438      |
# | loss                | 10.5     |
# | loss_bc             | -0       |
# | loss_f              | 0.151    |
# | loss_policy         | 0.151    |
# | loss_q              | 20.9     |
# | mean_episode_length | 334      |
# | mean_episode_reward | -73.9    |
# | norm_grads          | 16.8     |
# | norm_grads_policy   | 3.25     |
# | norm_grads_q        | 16.4     |
# | total_timesteps     | 30000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.00903  |
# | avg_norm_g          | 38.3     |
# | avg_norm_grads_f    | 38.3     |
# | avg_norm_k          | 1.96     |
# | avg_norm_k_dot_g    | 40.1     |
# | entropy             | 12.4     |
# | explained_variance  | -0.0169  |
# | fps                 | 435      |
# | loss                | 129      |
# | loss_bc             | -0       |
# | loss_f              | 11.4     |
# | loss_policy         | 11.4     |
# | loss_q              | 236      |
# | mean_episode_length | 347      |
# | mean_episode_reward | -71.5    |
# | norm_grads          | 56.3     |
# | norm_grads_policy   | 11.2     |
# | norm_grads_q        | 55.2     |
# | total_timesteps     | 32000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 35       |
# | avg_norm_grads_f    | 35       |
# | avg_norm_k          | 1.49     |
# | avg_norm_k_dot_g    | 20.4     |
# | entropy             | 6.93     |
# | explained_variance  | -0.0106  |
# | fps                 | 427      |
# | loss                | 42.6     |
# | loss_bc             | -0       |
# | loss_f              | 7.34     |
# | loss_policy         | 7.34     |
# | loss_q              | 70.6     |
# | mean_episode_length | 375      |
# | mean_episode_reward | -85.8    |
# | norm_grads          | 57.3     |
# | norm_grads_policy   | 45.8     |
# | norm_grads_q        | 34.4     |
# | total_timesteps     | 34000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 15.9     |
# | avg_norm_grads_f    | 15.9     |
# | avg_norm_k          | 1.96     |
# | avg_norm_k_dot_g    | 17.6     |
# | entropy             | 12.1     |
# | explained_variance  | -0.0238  |
# | fps                 | 424      |
# | loss                | 23.9     |
# | loss_bc             | -0       |
# | loss_f              | 4.6      |
# | loss_policy         | 4.6      |
# | loss_q              | 38.8     |
# | mean_episode_length | 406      |
# | mean_episode_reward | -69      |
# | norm_grads          | 33.8     |
# | norm_grads_policy   | 23.6     |
# | norm_grads_q        | 24.1     |
# | total_timesteps     | 36000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 1.78     |
# | avg_norm_grads_f    | 1.78     |
# | avg_norm_k          | 2.1      |
# | avg_norm_k_dot_g    | 1.78     |
# | entropy             | 23       |
# | explained_variance  | 0.0924   |
# | fps                 | 422      |
# | loss                | 0.528    |
# | loss_bc             | -0       |
# | loss_f              | 0.63     |
# | loss_policy         | 0.63     |
# | loss_q              | 0.257    |
# | mean_episode_length | 423      |
# | mean_episode_reward | -65.6    |
# | norm_grads          | 15.4     |
# | norm_grads_policy   | 0.348    |
# | norm_grads_q        | 15.4     |
# | total_timesteps     | 38000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.66     |
# | avg_norm_g          | 16.2     |
# | avg_norm_grads_f    | 14.1     |
# | avg_norm_k          | 2.05     |
# | avg_norm_k_dot_g    | 16.7     |
# | entropy             | 17.2     |
# | explained_variance  | 0.0576   |
# | fps                 | 419      |
# | loss                | 1.85     |
# | loss_bc             | -0       |
# | loss_f              | -3.25    |
# | loss_policy         | -3.25    |
# | loss_q              | 10.5     |
# | mean_episode_length | 471      |
# | mean_episode_reward | -51.7    |
# | norm_grads          | 12       |
# | norm_grads_policy   | 9.22     |
# | norm_grads_q        | 7.66     |
# | total_timesteps     | 40000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 28.5     |
# | avg_norm_grads_f    | 28.5     |
# | avg_norm_k          | 1.93     |
# | avg_norm_k_dot_g    | 28.6     |
# | entropy             | 12.6     |
# | explained_variance  | 0.00534  |
# | fps                 | 416      |
# | loss                | 80.1     |
# | loss_bc             | -0       |
# | loss_f              | 8.56     |
# | loss_policy         | 8.56     |
# | loss_q              | 143      |
# | mean_episode_length | 482      |
# | mean_episode_reward | -54.2    |
# | norm_grads          | 48.7     |
# | norm_grads_policy   | 17.1     |
# | norm_grads_q        | 45.6     |
# | total_timesteps     | 42000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.62     |
# | avg_norm_g          | 8.75     |
# | avg_norm_grads_f    | 7.67     |
# | avg_norm_k          | 1.93     |
# | avg_norm_k_dot_g    | 9.37     |
# | entropy             | 13.6     |
# | explained_variance  | -0.00767 |
# | fps                 | 411      |
# | loss                | 7.02     |
# | loss_bc             | -0       |
# | loss_f              | -1.51    |
# | loss_policy         | -1.51    |
# | loss_q              | 17.3     |
# | mean_episode_length | 494      |
# | mean_episode_reward | -50.9    |
# | norm_grads          | 10.1     |
# | norm_grads_policy   | 7.99     |
# | norm_grads_q        | 6.12     |
# | total_timesteps     | 44000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 60.4     |
# | avg_norm_grads_f    | 60.4     |
# | avg_norm_k          | 1.8      |
# | avg_norm_k_dot_g    | 58.1     |
# | entropy             | 9.66     |
# | explained_variance  | -0.00448 |
# | fps                 | 409      |
# | loss                | 274      |
# | loss_bc             | -0       |
# | loss_f              | 15.5     |
# | loss_policy         | 15.5     |
# | loss_q              | 518      |
# | mean_episode_length | 487      |
# | mean_episode_reward | -54.3    |
# | norm_grads          | 98.1     |
# | norm_grads_policy   | 33       |
# | norm_grads_q        | 92.3     |
# | total_timesteps     | 46000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 18.4     |
# | avg_norm_grads_f    | 18.4     |
# | avg_norm_k          | 1.97     |
# | avg_norm_k_dot_g    | 18.5     |
# | entropy             | 12.8     |
# | explained_variance  | -0.187   |
# | fps                 | 408      |
# | loss                | 31.1     |
# | loss_bc             | -0       |
# | loss_f              | 5.44     |
# | loss_policy         | 5.44     |
# | loss_q              | 51.6     |
# | mean_episode_length | 489      |
# | mean_episode_reward | -64.1    |
# | norm_grads          | 37.3     |
# | norm_grads_policy   | 24.7     |
# | norm_grads_q        | 28       |
# | total_timesteps     | 48000    |
# ----------------------------------

# %%
# Record & show video 
record_video('LunarLander-v2', model, video_length=1500, prefix='LunarLander-v2-50000')
show_videos('videos', prefix='LunarLander-v2-50000')
# Random Agent, after training
mean_reward_after_train = evaluate(model, num_steps=1500)
# Out:
# Saving video to  /content/videos/LunarLander-v2-50000-step-0-to-step-1500.mp4
# <video alt="videos/LunarLander-v2-50000-step-0-to-step-1500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
# Mean reward: -28.1 Num episodes: 3

# %%
# Train model
model.learn(total_timesteps=200000)
# Save model
model.save("ACER-LunarLander-v2-200000")
# Out:
# ----------------------------------
# | avg_norm_adj        | 0.702    |
# | avg_norm_g          | 4.86     |
# | avg_norm_grads_f    | 4.42     |
# | avg_norm_k          | 1.89     |
# | avg_norm_k_dot_g    | 4.91     |
# | entropy             | 4.55     |
# | explained_variance  | -0.103   |
# | fps                 | 0        |
# | loss                | 2.26     |
# | loss_bc             | -0       |
# | loss_f              | -0.779   |
# | loss_policy         | -0.779   |
# | loss_q              | 6.16     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 9.32     |
# | norm_grads_policy   | 8.74     |
# | norm_grads_q        | 3.24     |
# | total_timesteps     | 0        |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 2.81     |
# | avg_norm_g          | 24.2     |
# | avg_norm_grads_f    | 21.9     |
# | avg_norm_k          | 3.26     |
# | avg_norm_k_dot_g    | 32.5     |
# | entropy             | 7.99     |
# | explained_variance  | -0.063   |
# | fps                 | 405      |
# | loss                | 31       |
# | loss_bc             | -0       |
# | loss_f              | -4.85    |
# | loss_policy         | -4.85    |
# | loss_q              | 72       |
# | mean_episode_length | 396      |
# | mean_episode_reward | -77.4    |
# | norm_grads          | 43.7     |
# | norm_grads_policy   | 27.4     |
# | norm_grads_q        | 34.1     |
# | total_timesteps     | 2000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.442    |
# | avg_norm_grads_f    | 0.442    |
# | avg_norm_k          | 2.43     |
# | avg_norm_k_dot_g    | 0.447    |
# | entropy             | 14.1     |
# | explained_variance  | -0.283   |
# | fps                 | 401      |
# | loss                | 0.024    |
# | loss_bc             | -0       |
# | loss_f              | 0.138    |
# | loss_policy         | 0.138    |
# | loss_q              | 0.053    |
# | mean_episode_length | 382      |
# | mean_episode_reward | -52      |
# | norm_grads          | 6.26     |
# | norm_grads_policy   | 0.211    |
# | norm_grads_q        | 6.26     |
# | total_timesteps     | 4000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 4.9      |
# | avg_norm_g          | 19.4     |
# | avg_norm_grads_f    | 16.7     |
# | avg_norm_k          | 2.22     |
# | avg_norm_k_dot_g    | 19.4     |
# | entropy             | 14       |
# | explained_variance  | -0.0115  |
# | fps                 | 402      |
# | loss                | 179      |
# | loss_bc             | -0       |
# | loss_f              | -1.03    |
# | loss_policy         | -1.03    |
# | loss_q              | 361      |
# | mean_episode_length | 401      |
# | mean_episode_reward | -58.3    |
# | norm_grads          | 44.6     |
# | norm_grads_policy   | 21.3     |
# | norm_grads_q        | 39.2     |
# | total_timesteps     | 6000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 9.23     |
# | avg_norm_g          | 24.4     |
# | avg_norm_grads_f    | 18.9     |
# | avg_norm_k          | 1.39     |
# | avg_norm_k_dot_g    | 23.1     |
# | entropy             | 5.19     |
# | explained_variance  | -1.24    |
# | fps                 | 403      |
# | loss                | 571      |
# | loss_bc             | -0       |
# | loss_f              | 0.771    |
# | loss_policy         | 0.771    |
# | loss_q              | 1.14e+03 |
# | mean_episode_length | 421      |
# | mean_episode_reward | -47.2    |
# | norm_grads          | 211      |
# | norm_grads_policy   | 5.91     |
# | norm_grads_q        | 211      |
# | total_timesteps     | 8000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.7      |
# | avg_norm_g          | 6.08     |
# | avg_norm_grads_f    | 5        |
# | avg_norm_k          | 1.47     |
# | avg_norm_k_dot_g    | 6.14     |
# | entropy             | 3.12     |
# | explained_variance  | 9.44e-05 |
# | fps                 | 409      |
# | loss                | 12.5     |
# | loss_bc             | -0       |
# | loss_f              | -0.209   |
# | loss_policy         | -0.209   |
# | loss_q              | 25.6     |
# | mean_episode_length | 381      |
# | mean_episode_reward | -56.3    |
# | norm_grads          | 14.5     |
# | norm_grads_policy   | 4.62     |
# | norm_grads_q        | 13.7     |
# | total_timesteps     | 10000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.56     |
# | avg_norm_g          | 19       |
# | avg_norm_grads_f    | 17       |
# | avg_norm_k          | 2.21     |
# | avg_norm_k_dot_g    | 19.5     |
# | entropy             | 9.33     |
# | explained_variance  | 0.00851  |
# | fps                 | 417      |
# | loss                | 33.3     |
# | loss_bc             | -0       |
# | loss_f              | -4.49    |
# | loss_policy         | -4.49    |
# | loss_q              | 75.8     |
# | mean_episode_length | 340      |
# | mean_episode_reward | -65.1    |
# | norm_grads          | 34.9     |
# | norm_grads_policy   | 6.03     |
# | norm_grads_q        | 34.4     |
# | total_timesteps     | 12000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 57.4     |
# | avg_norm_grads_f    | 57.4     |
# | avg_norm_k          | 1.67     |
# | avg_norm_k_dot_g    | 41       |
# | entropy             | 8.65     |
# | explained_variance  | -0.177   |
# | fps                 | 423      |
# | loss                | 82.1     |
# | loss_bc             | -0       |
# | loss_f              | 11       |
# | loss_policy         | 11       |
# | loss_q              | 142      |
# | mean_episode_length | 303      |
# | mean_episode_reward | -77.6    |
# | norm_grads          | 59.7     |
# | norm_grads_policy   | 33.7     |
# | norm_grads_q        | 49.3     |
# | total_timesteps     | 14000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 19.8     |
# | avg_norm_g          | 44.6     |
# | avg_norm_grads_f    | 32.8     |
# | avg_norm_k          | 1.57     |
# | avg_norm_k_dot_g    | 44.5     |
# | entropy             | 3.69     |
# | explained_variance  | -0.00722 |
# | fps                 | 429      |
# | loss                | 569      |
# | loss_bc             | -0       |
# | loss_f              | -0.97    |
# | loss_policy         | -0.97    |
# | loss_q              | 1.14e+03 |
# | mean_episode_length | 246      |
# | mean_episode_reward | -101     |
# | norm_grads          | 172      |
# | norm_grads_policy   | 9.33     |
# | norm_grads_q        | 172      |
# | total_timesteps     | 16000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.853    |
# | avg_norm_g          | 6.91     |
# | avg_norm_grads_f    | 6.37     |
# | avg_norm_k          | 2.25     |
# | avg_norm_k_dot_g    | 7.01     |
# | entropy             | 19.1     |
# | explained_variance  | 0.0949   |
# | fps                 | 433      |
# | loss                | 1.7      |
# | loss_bc             | -0       |
# | loss_f              | -0.0843  |
# | loss_policy         | -0.0843  |
# | loss_q              | 3.95     |
# | mean_episode_length | 185      |
# | mean_episode_reward | -138     |
# | norm_grads          | 9.57     |
# | norm_grads_policy   | 9.36     |
# | norm_grads_q        | 2.01     |
# | total_timesteps     | 18000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 48.4     |
# | avg_norm_grads_f    | 48.4     |
# | avg_norm_k          | 2.07     |
# | avg_norm_k_dot_g    | 50       |
# | entropy             | 13.3     |
# | explained_variance  | 0.0242   |
# | fps                 | 438      |
# | loss                | 259      |
# | loss_bc             | -0       |
# | loss_f              | 14.1     |
# | loss_policy         | 14.1     |
# | loss_q              | 489      |
# | mean_episode_length | 166      |
# | mean_episode_reward | -144     |
# | norm_grads          | 86.3     |
# | norm_grads_policy   | 27.5     |
# | norm_grads_q        | 81.7     |
# | total_timesteps     | 20000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.238    |
# | avg_norm_g          | 1.79     |
# | avg_norm_grads_f    | 1.64     |
# | avg_norm_k          | 2.02     |
# | avg_norm_k_dot_g    | 1.87     |
# | entropy             | 7.36     |
# | explained_variance  | -0.677   |
# | fps                 | 439      |
# | loss                | -0.0394  |
# | loss_bc             | -0       |
# | loss_f              | -0.0995  |
# | loss_policy         | -0.0995  |
# | loss_q              | 0.267    |
# | mean_episode_length | 164      |
# | mean_episode_reward | -143     |
# | norm_grads          | 0.431    |
# | norm_grads_policy   | 0.32     |
# | norm_grads_q        | 0.289    |
# | total_timesteps     | 22000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 7.88     |
# | avg_norm_g          | 25.8     |
# | avg_norm_grads_f    | 21.1     |
# | avg_norm_k          | 1.63     |
# | avg_norm_k_dot_g    | 21.5     |
# | entropy             | 7.04     |
# | explained_variance  | -0.277   |
# | fps                 | 432      |
# | loss                | 49.8     |
# | loss_bc             | -0       |
# | loss_f              | -5.07    |
# | loss_policy         | -5.07    |
# | loss_q              | 110      |
# | mean_episode_length | 213      |
# | mean_episode_reward | -128     |
# | norm_grads          | 53.2     |
# | norm_grads_policy   | 30.7     |
# | norm_grads_q        | 43.4     |
# | total_timesteps     | 24000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 27.6     |
# | avg_norm_g          | 73.9     |
# | avg_norm_grads_f    | 57.5     |
# | avg_norm_k          | 1.6      |
# | avg_norm_k_dot_g    | 76.7     |
# | entropy             | 3.58     |
# | explained_variance  | -0.0388  |
# | fps                 | 433      |
# | loss                | 1.65e+03 |
# | loss_bc             | -0       |
# | loss_f              | -5.04    |
# | loss_policy         | -5.04    |
# | loss_q              | 3.31e+03 |
# | mean_episode_length | 226      |
# | mean_episode_reward | -104     |
# | norm_grads          | 488      |
# | norm_grads_policy   | 50.4     |
# | norm_grads_q        | 486      |
# | total_timesteps     | 26000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.00596  |
# | avg_norm_g          | 0.65     |
# | avg_norm_grads_f    | 0.645    |
# | avg_norm_k          | 3.01     |
# | avg_norm_k_dot_g    | 0.648    |
# | entropy             | 1.26     |
# | explained_variance  | 0.698    |
# | fps                 | 434      |
# | loss                | 0.132    |
# | loss_bc             | -0       |
# | loss_f              | -0.00569 |
# | loss_policy         | -0.00569 |
# | loss_q              | 0.3      |
# | mean_episode_length | 243      |
# | mean_episode_reward | -72.3    |
# | norm_grads          | 7.28     |
# | norm_grads_policy   | 0.0655   |
# | norm_grads_q        | 7.28     |
# | total_timesteps     | 28000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 17.5     |
# | avg_norm_g          | 67.3     |
# | avg_norm_grads_f    | 58.5     |
# | avg_norm_k          | 1.85     |
# | avg_norm_k_dot_g    | 60.9     |
# | entropy             | 10.3     |
# | explained_variance  | -0.0176  |
# | fps                 | 435      |
# | loss                | 336      |
# | loss_bc             | -0       |
# | loss_f              | -16.1    |
# | loss_policy         | -16.1    |
# | loss_q              | 703      |
# | mean_episode_length | 263      |
# | mean_episode_reward | -45.4    |
# | norm_grads          | 108      |
# | norm_grads_policy   | 58.8     |
# | norm_grads_q        | 90.4     |
# | total_timesteps     | 30000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 31.6     |
# | avg_norm_grads_f    | 31.6     |
# | avg_norm_k          | 2.36     |
# | avg_norm_k_dot_g    | 26.2     |
# | entropy             | 9.94     |
# | explained_variance  | -0.11    |
# | fps                 | 434      |
# | loss                | 112      |
# | loss_bc             | -0       |
# | loss_f              | 8.49     |
# | loss_policy         | 8.49     |
# | loss_q              | 207      |
# | mean_episode_length | 287      |
# | mean_episode_reward | -25.7    |
# | norm_grads          | 113      |
# | norm_grads_policy   | 102      |
# | norm_grads_q        | 49.5     |
# | total_timesteps     | 32000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 5.3      |
# | avg_norm_g          | 24.2     |
# | avg_norm_grads_f    | 21.7     |
# | avg_norm_k          | 2.05     |
# | avg_norm_k_dot_g    | 19.1     |
# | entropy             | 3.15     |
# | explained_variance  | -0.0202  |
# | fps                 | 426      |
# | loss                | 185      |
# | loss_bc             | -0       |
# | loss_f              | -4.29    |
# | loss_policy         | -4.29    |
# | loss_q              | 379      |
# | mean_episode_length | 293      |
# | mean_episode_reward | -25.7    |
# | norm_grads          | 87.1     |
# | norm_grads_policy   | 77.6     |
# | norm_grads_q        | 39.4     |
# | total_timesteps     | 34000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 19.8     |
# | avg_norm_g          | 48.4     |
# | avg_norm_grads_f    | 37       |
# | avg_norm_k          | 1.6      |
# | avg_norm_k_dot_g    | 30.8     |
# | entropy             | 2.03     |
# | explained_variance  | -0.0725  |
# | fps                 | 422      |
# | loss                | 316      |
# | loss_bc             | -0       |
# | loss_f              | -11.6    |
# | loss_policy         | -11.6    |
# | loss_q              | 656      |
# | mean_episode_length | 291      |
# | mean_episode_reward | -26.2    |
# | norm_grads          | 184      |
# | norm_grads_policy   | 175      |
# | norm_grads_q        | 56.7     |
# | total_timesteps     | 36000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.207    |
# | avg_norm_g          | 2.46     |
# | avg_norm_grads_f    | 2.31     |
# | avg_norm_k          | 1.89     |
# | avg_norm_k_dot_g    | 2.65     |
# | entropy             | 13.2     |
# | explained_variance  | -0.0317  |
# | fps                 | 421      |
# | loss                | 0.686    |
# | loss_bc             | -0       |
# | loss_f              | -0.0187  |
# | loss_policy         | -0.0187  |
# | loss_q              | 1.67     |
# | mean_episode_length | 309      |
# | mean_episode_reward | -31.2    |
# | norm_grads          | 5.8      |
# | norm_grads_policy   | 5.5      |
# | norm_grads_q        | 1.84     |
# | total_timesteps     | 38000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.404    |
# | avg_norm_g          | 59       |
# | avg_norm_grads_f    | 58.6     |
# | avg_norm_k          | 1.58     |
# | avg_norm_k_dot_g    | 55.5     |
# | entropy             | 10.2     |
# | explained_variance  | -0.00596 |
# | fps                 | 418      |
# | loss                | 261      |
# | loss_bc             | -0       |
# | loss_f              | 15.3     |
# | loss_policy         | 15.3     |
# | loss_q              | 492      |
# | mean_episode_length | 334      |
# | mean_episode_reward | -20.9    |
# | norm_grads          | 75.2     |
# | norm_grads_policy   | 28.1     |
# | norm_grads_q        | 69.8     |
# | total_timesteps     | 40000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.303    |
# | avg_norm_g          | 2.29     |
# | avg_norm_grads_f    | 2.03     |
# | avg_norm_k          | 2.38     |
# | avg_norm_k_dot_g    | 2.49     |
# | entropy             | 13.7     |
# | explained_variance  | -0.0421  |
# | fps                 | 417      |
# | loss                | -0.263   |
# | loss_bc             | -0       |
# | loss_f              | -0.679   |
# | loss_policy         | -0.679   |
# | loss_q              | 1.11     |
# | mean_episode_length | 340      |
# | mean_episode_reward | -16.3    |
# | norm_grads          | 5.36     |
# | norm_grads_policy   | 2.73     |
# | norm_grads_q        | 4.61     |
# | total_timesteps     | 42000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 8.95     |
# | avg_norm_grads_f    | 8.95     |
# | avg_norm_k          | 1.75     |
# | avg_norm_k_dot_g    | 8.91     |
# | entropy             | 2.73     |
# | explained_variance  | -0.132   |
# | fps                 | 414      |
# | loss                | 25.5     |
# | loss_bc             | -0       |
# | loss_f              | 0.734    |
# | loss_policy         | 0.734    |
# | loss_q              | 49.7     |
# | mean_episode_length | 371      |
# | mean_episode_reward | -8.82    |
# | norm_grads          | 38.4     |
# | norm_grads_policy   | 4.45     |
# | norm_grads_q        | 38.1     |
# | total_timesteps     | 44000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 50       |
# | avg_norm_grads_f    | 50       |
# | avg_norm_k          | 1.95     |
# | avg_norm_k_dot_g    | 46.6     |
# | entropy             | 8.44     |
# | explained_variance  | 0.445    |
# | fps                 | 412      |
# | loss                | 129      |
# | loss_bc             | -0       |
# | loss_f              | 9.9      |
# | loss_policy         | 9.9      |
# | loss_q              | 239      |
# | mean_episode_length | 398      |
# | mean_episode_reward | 15.7     |
# | norm_grads          | 187      |
# | norm_grads_policy   | 42.6     |
# | norm_grads_q        | 182      |
# | total_timesteps     | 46000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 49.8     |
# | avg_norm_grads_f    | 49.8     |
# | avg_norm_k          | 1.83     |
# | avg_norm_k_dot_g    | 49.8     |
# | entropy             | 10.7     |
# | explained_variance  | -0.501   |
# | fps                 | 412      |
# | loss                | 254      |
# | loss_bc             | -0       |
# | loss_f              | 13.1     |
# | loss_policy         | 13.1     |
# | loss_q              | 482      |
# | mean_episode_length | 409      |
# | mean_episode_reward | 7.12     |
# | norm_grads          | 136      |
# | norm_grads_policy   | 65.7     |
# | norm_grads_q        | 120      |
# | total_timesteps     | 48000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.196    |
# | avg_norm_g          | 9.1      |
# | avg_norm_grads_f    | 8.97     |
# | avg_norm_k          | 1.73     |
# | avg_norm_k_dot_g    | 6.09     |
# | entropy             | 7.18     |
# | explained_variance  | 0.132    |
# | fps                 | 411      |
# | loss                | 6.54     |
# | loss_bc             | -0       |
# | loss_f              | 1.27     |
# | loss_policy         | 1.27     |
# | loss_q              | 10.7     |
# | mean_episode_length | 398      |
# | mean_episode_reward | -2.41    |
# | norm_grads          | 13.7     |
# | norm_grads_policy   | 4.55     |
# | norm_grads_q        | 12.9     |
# | total_timesteps     | 50000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 27.1     |
# | avg_norm_g          | 108      |
# | avg_norm_grads_f    | 95       |
# | avg_norm_k          | 1.5      |
# | avg_norm_k_dot_g    | 89       |
# | entropy             | 1.84     |
# | explained_variance  | -0.122   |
# | fps                 | 410      |
# | loss                | 1.85e+03 |
# | loss_bc             | -0       |
# | loss_f              | -12.2    |
# | loss_policy         | -12.2    |
# | loss_q              | 3.72e+03 |
# | mean_episode_length | 405      |
# | mean_episode_reward | 25       |
# | norm_grads          | 994      |
# | norm_grads_policy   | 100      |
# | norm_grads_q        | 989      |
# | total_timesteps     | 52000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.09     |
# | avg_norm_g          | 11.6     |
# | avg_norm_grads_f    | 9.31     |
# | avg_norm_k          | 2.02     |
# | avg_norm_k_dot_g    | 13.4     |
# | entropy             | 12.4     |
# | explained_variance  | 0.0144   |
# | fps                 | 407      |
# | loss                | 17.4     |
# | loss_bc             | -0       |
# | loss_f              | -3.24    |
# | loss_policy         | -3.24    |
# | loss_q              | 41.5     |
# | mean_episode_length | 409      |
# | mean_episode_reward | 30.8     |
# | norm_grads          | 23.4     |
# | norm_grads_policy   | 13.5     |
# | norm_grads_q        | 19.1     |
# | total_timesteps     | 54000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 9.46     |
# | avg_norm_grads_f    | 9.46     |
# | avg_norm_k          | 1.71     |
# | avg_norm_k_dot_g    | 8.62     |
# | entropy             | 12.8     |
# | explained_variance  | -0.12    |
# | fps                 | 409      |
# | loss                | 10.2     |
# | loss_bc             | -0       |
# | loss_f              | 2.62     |
# | loss_policy         | 2.62     |
# | loss_q              | 15.5     |
# | mean_episode_length | 372      |
# | mean_episode_reward | -7.51    |
# | norm_grads          | 15.8     |
# | norm_grads_policy   | 3.9      |
# | norm_grads_q        | 15.3     |
# | total_timesteps     | 56000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.21     |
# | avg_norm_g          | 10.4     |
# | avg_norm_grads_f    | 10.3     |
# | avg_norm_k          | 1.78     |
# | avg_norm_k_dot_g    | 10       |
# | entropy             | 12.1     |
# | explained_variance  | -0.00694 |
# | fps                 | 409      |
# | loss                | 13.6     |
# | loss_bc             | -0       |
# | loss_f              | 2.32     |
# | loss_policy         | 2.32     |
# | loss_q              | 22.8     |
# | mean_episode_length | 339      |
# | mean_episode_reward | -29.6    |
# | norm_grads          | 14.3     |
# | norm_grads_policy   | 1.7      |
# | norm_grads_q        | 14.2     |
# | total_timesteps     | 58000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 105      |
# | avg_norm_grads_f    | 105      |
# | avg_norm_k          | 1.24     |
# | avg_norm_k_dot_g    | 70       |
# | entropy             | 3.82     |
# | explained_variance  | -0.16    |
# | fps                 | 410      |
# | loss                | 162      |
# | loss_bc             | -0       |
# | loss_f              | 6.79     |
# | loss_policy         | 6.79     |
# | loss_q              | 310      |
# | mean_episode_length | 301      |
# | mean_episode_reward | -56.2    |
# | norm_grads          | 97.8     |
# | norm_grads_policy   | 15.1     |
# | norm_grads_q        | 96.7     |
# | total_timesteps     | 60000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 73.7     |
# | avg_norm_grads_f    | 73.7     |
# | avg_norm_k          | 1.64     |
# | avg_norm_k_dot_g    | 77       |
# | entropy             | 11.7     |
# | explained_variance  | -0.0308  |
# | fps                 | 410      |
# | loss                | 439      |
# | loss_bc             | -0       |
# | loss_f              | 20.7     |
# | loss_policy         | 20.7     |
# | loss_q              | 837      |
# | mean_episode_length | 298      |
# | mean_episode_reward | -67.2    |
# | norm_grads          | 138      |
# | norm_grads_policy   | 59.1     |
# | norm_grads_q        | 125      |
# | total_timesteps     | 62000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 44.5     |
# | avg_norm_grads_f    | 44.5     |
# | avg_norm_k          | 1.5      |
# | avg_norm_k_dot_g    | 47.9     |
# | entropy             | 10.2     |
# | explained_variance  | -0.0885  |
# | fps                 | 410      |
# | loss                | 137      |
# | loss_bc             | -0       |
# | loss_f              | 11.6     |
# | loss_policy         | 11.6     |
# | loss_q              | 252      |
# | mean_episode_length | 269      |
# | mean_episode_reward | -115     |
# | norm_grads          | 93.5     |
# | norm_grads_policy   | 54.3     |
# | norm_grads_q        | 76.2     |
# | total_timesteps     | 64000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 30.7     |
# | avg_norm_g          | 69.7     |
# | avg_norm_grads_f    | 57.1     |
# | avg_norm_k          | 1.12     |
# | avg_norm_k_dot_g    | 42.5     |
# | entropy             | 0.764    |
# | explained_variance  | 0.0104   |
# | fps                 | 411      |
# | loss                | 77.6     |
# | loss_bc             | -0       |
# | loss_f              | -5.37    |
# | loss_policy         | -5.37    |
# | loss_q              | 166      |
# | mean_episode_length | 278      |
# | mean_episode_reward | -102     |
# | norm_grads          | 72.4     |
# | norm_grads_policy   | 47.2     |
# | norm_grads_q        | 55       |
# | total_timesteps     | 66000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.548    |
# | avg_norm_g          | 5.06     |
# | avg_norm_grads_f    | 4.72     |
# | avg_norm_k          | 1.83     |
# | avg_norm_k_dot_g    | 4.99     |
# | entropy             | 11.9     |
# | explained_variance  | 0.725    |
# | fps                 | 410      |
# | loss                | 3.28     |
# | loss_bc             | -0       |
# | loss_f              | 0.267    |
# | loss_policy         | 0.267    |
# | loss_q              | 6.25     |
# | mean_episode_length | 290      |
# | mean_episode_reward | -84.7    |
# | norm_grads          | 16       |
# | norm_grads_policy   | 3.65     |
# | norm_grads_q        | 15.6     |
# | total_timesteps     | 68000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 8.65     |
# | avg_norm_g          | 32.6     |
# | avg_norm_grads_f    | 27.4     |
# | avg_norm_k          | 2.08     |
# | avg_norm_k_dot_g    | 33.9     |
# | entropy             | 10.1     |
# | explained_variance  | -0.225   |
# | fps                 | 411      |
# | loss                | 90.1     |
# | loss_bc             | -0       |
# | loss_f              | -6.26    |
# | loss_policy         | -6.26    |
# | loss_q              | 193      |
# | mean_episode_length | 286      |
# | mean_episode_reward | -61.4    |
# | norm_grads          | 180      |
# | norm_grads_policy   | 18.1     |
# | norm_grads_q        | 179      |
# | total_timesteps     | 70000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.74     |
# | avg_norm_g          | 25.8     |
# | avg_norm_grads_f    | 22.7     |
# | avg_norm_k          | 1.97     |
# | avg_norm_k_dot_g    | 32.9     |
# | entropy             | 5.1      |
# | explained_variance  | 0.0736   |
# | fps                 | 412      |
# | loss                | 27.1     |
# | loss_bc             | -0       |
# | loss_f              | 2.18     |
# | loss_policy         | 2.18     |
# | loss_q              | 50       |
# | mean_episode_length | 284      |
# | mean_episode_reward | -47      |
# | norm_grads          | 18.5     |
# | norm_grads_policy   | 4.16     |
# | norm_grads_q        | 18       |
# | total_timesteps     | 72000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 19.1     |
# | avg_norm_g          | 80.5     |
# | avg_norm_grads_f    | 60.1     |
# | avg_norm_k          | 2.21     |
# | avg_norm_k_dot_g    | 149      |
# | entropy             | 4.7      |
# | explained_variance  | 0.137    |
# | fps                 | 412      |
# | loss                | 11.1     |
# | loss_bc             | -0       |
# | loss_f              | -5.8     |
# | loss_policy         | -5.8     |
# | loss_q              | 34       |
# | mean_episode_length | 278      |
# | mean_episode_reward | -35      |
# | norm_grads          | 36.5     |
# | norm_grads_policy   | 26.5     |
# | norm_grads_q        | 25.1     |
# | total_timesteps     | 74000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.24     |
# | avg_norm_g          | 12.4     |
# | avg_norm_grads_f    | 11.6     |
# | avg_norm_k          | 1.45     |
# | avg_norm_k_dot_g    | 12.4     |
# | entropy             | 10.6     |
# | explained_variance  | 0.537    |
# | fps                 | 412      |
# | loss                | 15.1     |
# | loss_bc             | -0       |
# | loss_f              | 1.72     |
# | loss_policy         | 1.72     |
# | loss_q              | 26.9     |
# | mean_episode_length | 294      |
# | mean_episode_reward | -39.5    |
# | norm_grads          | 27.4     |
# | norm_grads_policy   | 2.64     |
# | norm_grads_q        | 27.2     |
# | total_timesteps     | 76000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0244   |
# | avg_norm_g          | 26.7     |
# | avg_norm_grads_f    | 26.7     |
# | avg_norm_k          | 2.71     |
# | avg_norm_k_dot_g    | 21.7     |
# | entropy             | 9.07     |
# | explained_variance  | 0.276    |
# | fps                 | 412      |
# | loss                | 115      |
# | loss_bc             | -0       |
# | loss_f              | 6.6      |
# | loss_policy         | 6.6      |
# | loss_q              | 216      |
# | mean_episode_length | 308      |
# | mean_episode_reward | -45.4    |
# | norm_grads          | 111      |
# | norm_grads_policy   | 81.8     |
# | norm_grads_q        | 74.7     |
# | total_timesteps     | 78000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.06     |
# | avg_norm_g          | 6.43     |
# | avg_norm_grads_f    | 5.82     |
# | avg_norm_k          | 2.02     |
# | avg_norm_k_dot_g    | 6.27     |
# | entropy             | 14.8     |
# | explained_variance  | -0.434   |
# | fps                 | 411      |
# | loss                | 2.36     |
# | loss_bc             | -0       |
# | loss_f              | -0.929   |
# | loss_policy         | -0.929   |
# | loss_q              | 6.88     |
# | mean_episode_length | 309      |
# | mean_episode_reward | -31.3    |
# | norm_grads          | 14.9     |
# | norm_grads_policy   | 8.3      |
# | norm_grads_q        | 12.3     |
# | total_timesteps     | 80000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.00832  |
# | avg_norm_g          | 4.27     |
# | avg_norm_grads_f    | 4.26     |
# | avg_norm_k          | 1.78     |
# | avg_norm_k_dot_g    | 4.07     |
# | entropy             | 10.4     |
# | explained_variance  | -0.6     |
# | fps                 | 408      |
# | loss                | 3.45     |
# | loss_bc             | -0       |
# | loss_f              | 1.08     |
# | loss_policy         | 1.08     |
# | loss_q              | 4.95     |
# | mean_episode_length | 343      |
# | mean_episode_reward | -23.4    |
# | norm_grads          | 33.9     |
# | norm_grads_policy   | 18.5     |
# | norm_grads_q        | 28.3     |
# | total_timesteps     | 82000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 29.1     |
# | avg_norm_grads_f    | 29.1     |
# | avg_norm_k          | 1.9      |
# | avg_norm_k_dot_g    | 34.7     |
# | entropy             | 9.81     |
# | explained_variance  | -0.015   |
# | fps                 | 406      |
# | loss                | 53.2     |
# | loss_bc             | -0       |
# | loss_f              | 7.1      |
# | loss_policy         | 7.1      |
# | loss_q              | 92.4     |
# | mean_episode_length | 371      |
# | mean_episode_reward | -15.6    |
# | norm_grads          | 70.7     |
# | norm_grads_policy   | 61.2     |
# | norm_grads_q        | 35.4     |
# | total_timesteps     | 84000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.861    |
# | avg_norm_g          | 3.97     |
# | avg_norm_grads_f    | 3.37     |
# | avg_norm_k          | 1.71     |
# | avg_norm_k_dot_g    | 4.16     |
# | entropy             | 11.4     |
# | explained_variance  | 0.771    |
# | fps                 | 405      |
# | loss                | 1.14     |
# | loss_bc             | -0       |
# | loss_f              | -0.807   |
# | loss_policy         | -0.807   |
# | loss_q              | 4.12     |
# | mean_episode_length | 383      |
# | mean_episode_reward | -10.4    |
# | norm_grads          | 18.1     |
# | norm_grads_policy   | 0.484    |
# | norm_grads_q        | 18.1     |
# | total_timesteps     | 86000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.08     |
# | avg_norm_g          | 11.8     |
# | avg_norm_grads_f    | 10.1     |
# | avg_norm_k          | 1.88     |
# | avg_norm_k_dot_g    | 11.5     |
# | entropy             | 8.86     |
# | explained_variance  | 0.714    |
# | fps                 | 404      |
# | loss                | 21.7     |
# | loss_bc             | -0       |
# | loss_f              | -2.21    |
# | loss_policy         | -2.21    |
# | loss_q              | 48       |
# | mean_episode_length | 410      |
# | mean_episode_reward | 1.38     |
# | norm_grads          | 66.7     |
# | norm_grads_policy   | 33.6     |
# | norm_grads_q        | 57.6     |
# | total_timesteps     | 88000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.603    |
# | avg_norm_g          | 3.01     |
# | avg_norm_grads_f    | 2.66     |
# | avg_norm_k          | 1.89     |
# | avg_norm_k_dot_g    | 2.74     |
# | entropy             | 11.3     |
# | explained_variance  | 0.189    |
# | fps                 | 403      |
# | loss                | 1.34     |
# | loss_bc             | -0       |
# | loss_f              | -0.636   |
# | loss_policy         | -0.636   |
# | loss_q              | 4.19     |
# | mean_episode_length | 419      |
# | mean_episode_reward | 11.4     |
# | norm_grads          | 26.1     |
# | norm_grads_policy   | 9.73     |
# | norm_grads_q        | 24.2     |
# | total_timesteps     | 90000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 14.7     |
# | avg_norm_grads_f    | 14.7     |
# | avg_norm_k          | 2.33     |
# | avg_norm_k_dot_g    | 16.5     |
# | entropy             | 9.28     |
# | explained_variance  | -0.349   |
# | fps                 | 401      |
# | loss                | 20.2     |
# | loss_bc             | -0       |
# | loss_f              | 3.29     |
# | loss_policy         | 3.29     |
# | loss_q              | 34       |
# | mean_episode_length | 450      |
# | mean_episode_reward | 20.6     |
# | norm_grads          | 144      |
# | norm_grads_policy   | 48.8     |
# | norm_grads_q        | 136      |
# | total_timesteps     | 92000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 9.86     |
# | avg_norm_g          | 43.3     |
# | avg_norm_grads_f    | 30.8     |
# | avg_norm_k          | 3.05     |
# | avg_norm_k_dot_g    | 80.1     |
# | entropy             | 3.41     |
# | explained_variance  | -0.0832  |
# | fps                 | 400      |
# | loss                | 60.1     |
# | loss_bc             | -0       |
# | loss_f              | -5.76    |
# | loss_policy         | -5.76    |
# | loss_q              | 132      |
# | mean_episode_length | 459      |
# | mean_episode_reward | 59.8     |
# | norm_grads          | 115      |
# | norm_grads_policy   | 30.6     |
# | norm_grads_q        | 111      |
# | total_timesteps     | 94000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 6.6      |
# | avg_norm_grads_f    | 6.6      |
# | avg_norm_k          | 1.58     |
# | avg_norm_k_dot_g    | 6.7      |
# | entropy             | 10.3     |
# | explained_variance  | 0.379    |
# | fps                 | 398      |
# | loss                | 6.04     |
# | loss_bc             | -0       |
# | loss_f              | 1.58     |
# | loss_policy         | 1.58     |
# | loss_q              | 9.13     |
# | mean_episode_length | 487      |
# | mean_episode_reward | 70.2     |
# | norm_grads          | 26.3     |
# | norm_grads_policy   | 15.8     |
# | norm_grads_q        | 21.1     |
# | total_timesteps     | 96000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0477   |
# | avg_norm_g          | 10.2     |
# | avg_norm_grads_f    | 10.1     |
# | avg_norm_k          | 1.61     |
# | avg_norm_k_dot_g    | 10.1     |
# | entropy             | 8.22     |
# | explained_variance  | 0.829    |
# | fps                 | 395      |
# | loss                | 18.4     |
# | loss_bc             | -0       |
# | loss_f              | 2.04     |
# | loss_policy         | 2.04     |
# | loss_q              | 32.9     |
# | mean_episode_length | 492      |
# | mean_episode_reward | 62       |
# | norm_grads          | 75.8     |
# | norm_grads_policy   | 19.3     |
# | norm_grads_q        | 73.3     |
# | total_timesteps     | 98000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 19.3     |
# | avg_norm_grads_f    | 19.3     |
# | avg_norm_k          | 1.99     |
# | avg_norm_k_dot_g    | 23.1     |
# | entropy             | 9.16     |
# | explained_variance  | -0.244   |
# | fps                 | 394      |
# | loss                | 34.9     |
# | loss_bc             | -0       |
# | loss_f              | 4.84     |
# | loss_policy         | 4.84     |
# | loss_q              | 60.3     |
# | mean_episode_length | 506      |
# | mean_episode_reward | 66.5     |
# | norm_grads          | 155      |
# | norm_grads_policy   | 86       |
# | norm_grads_q        | 129      |
# | total_timesteps     | 100000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 7        |
# | avg_norm_g          | 26.3     |
# | avg_norm_grads_f    | 23       |
# | avg_norm_k          | 1.53     |
# | avg_norm_k_dot_g    | 17.3     |
# | entropy             | 11.2     |
# | explained_variance  | 0.441    |
# | fps                 | 392      |
# | loss                | 21.9     |
# | loss_bc             | -0       |
# | loss_f              | -5.49    |
# | loss_policy         | -5.49    |
# | loss_q              | 55       |
# | mean_episode_length | 488      |
# | mean_episode_reward | 50.9     |
# | norm_grads          | 95       |
# | norm_grads_policy   | 36.6     |
# | norm_grads_q        | 87.7     |
# | total_timesteps     | 102000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.735    |
# | avg_norm_g          | 11.3     |
# | avg_norm_grads_f    | 10.9     |
# | avg_norm_k          | 2.14     |
# | avg_norm_k_dot_g    | 11.4     |
# | entropy             | 10       |
# | explained_variance  | 0.4      |
# | fps                 | 389      |
# | loss                | 13.7     |
# | loss_bc             | -0       |
# | loss_f              | 1.22     |
# | loss_policy         | 1.22     |
# | loss_q              | 25.1     |
# | mean_episode_length | 487      |
# | mean_episode_reward | 41.4     |
# | norm_grads          | 30       |
# | norm_grads_policy   | 7.9      |
# | norm_grads_q        | 28.9     |
# | total_timesteps     | 104000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 8.84     |
# | avg_norm_grads_f    | 8.84     |
# | avg_norm_k          | 1.83     |
# | avg_norm_k_dot_g    | 14.3     |
# | entropy             | 8.71     |
# | explained_variance  | 0.898    |
# | fps                 | 388      |
# | loss                | 7.09     |
# | loss_bc             | -0       |
# | loss_f              | 2.22     |
# | loss_policy         | 2.22     |
# | loss_q              | 9.92     |
# | mean_episode_length | 510      |
# | mean_episode_reward | 33.1     |
# | norm_grads          | 43.3     |
# | norm_grads_policy   | 25.6     |
# | norm_grads_q        | 34.9     |
# | total_timesteps     | 106000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.43     |
# | avg_norm_grads_f    | 4.43     |
# | avg_norm_k          | 1.66     |
# | avg_norm_k_dot_g    | 4.68     |
# | entropy             | 10.3     |
# | explained_variance  | 0.895    |
# | fps                 | 387      |
# | loss                | 2.33     |
# | loss_bc             | -0       |
# | loss_f              | 1.15     |
# | loss_policy         | 1.15     |
# | loss_q              | 2.57     |
# | mean_episode_length | 511      |
# | mean_episode_reward | 56.4     |
# | norm_grads          | 23.7     |
# | norm_grads_policy   | 18       |
# | norm_grads_q        | 15.4     |
# | total_timesteps     | 108000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 45.2     |
# | avg_norm_grads_f    | 45.2     |
# | avg_norm_k          | 1.71     |
# | avg_norm_k_dot_g    | 61       |
# | entropy             | 3        |
# | explained_variance  | 0.00525  |
# | fps                 | 387      |
# | loss                | 27.4     |
# | loss_bc             | -0       |
# | loss_f              | 3.51     |
# | loss_policy         | 3.51     |
# | loss_q              | 47.9     |
# | mean_episode_length | 530      |
# | mean_episode_reward | 70.1     |
# | norm_grads          | 204      |
# | norm_grads_policy   | 34.9     |
# | norm_grads_q        | 201      |
# | total_timesteps     | 110000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 12.3     |
# | avg_norm_grads_f    | 12.3     |
# | avg_norm_k          | 1.65     |
# | avg_norm_k_dot_g    | 12.1     |
# | entropy             | 10.1     |
# | explained_variance  | -0.45    |
# | fps                 | 387      |
# | loss                | 19.3     |
# | loss_bc             | -0       |
# | loss_f              | 3.24     |
# | loss_policy         | 3.24     |
# | loss_q              | 32.3     |
# | mean_episode_length | 505      |
# | mean_episode_reward | 80.2     |
# | norm_grads          | 55.6     |
# | norm_grads_policy   | 38.8     |
# | norm_grads_q        | 39.9     |
# | total_timesteps     | 112000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.3      |
# | avg_norm_grads_f    | 4.3      |
# | avg_norm_k          | 1.99     |
# | avg_norm_k_dot_g    | 4.22     |
# | entropy             | 7.58     |
# | explained_variance  | 0.598    |
# | fps                 | 386      |
# | loss                | 4.18     |
# | loss_bc             | -0       |
# | loss_f              | 0.699    |
# | loss_policy         | 0.699    |
# | loss_q              | 7.1      |
# | mean_episode_length | 514      |
# | mean_episode_reward | 66.3     |
# | norm_grads          | 30.3     |
# | norm_grads_policy   | 5.09     |
# | norm_grads_q        | 29.9     |
# | total_timesteps     | 114000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.97     |
# | avg_norm_g          | 9.59     |
# | avg_norm_grads_f    | 8.34     |
# | avg_norm_k          | 2.17     |
# | avg_norm_k_dot_g    | 9.97     |
# | entropy             | 13.7     |
# | explained_variance  | 0.272    |
# | fps                 | 384      |
# | loss                | 1.17     |
# | loss_bc             | -0       |
# | loss_f              | -2.52    |
# | loss_policy         | -2.52    |
# | loss_q              | 7.65     |
# | mean_episode_length | 508      |
# | mean_episode_reward | 65.2     |
# | norm_grads          | 47.1     |
# | norm_grads_policy   | 7.14     |
# | norm_grads_q        | 46.5     |
# | total_timesteps     | 116000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 5.98     |
# | avg_norm_g          | 11.6     |
# | avg_norm_grads_f    | 6.55     |
# | avg_norm_k          | 1.49     |
# | avg_norm_k_dot_g    | 12       |
# | entropy             | 11.4     |
# | explained_variance  | 0.69     |
# | fps                 | 382      |
# | loss                | 26.4     |
# | loss_bc             | -0       |
# | loss_f              | -2.58    |
# | loss_policy         | -2.58    |
# | loss_q              | 58.2     |
# | mean_episode_length | 520      |
# | mean_episode_reward | 66.5     |
# | norm_grads          | 70       |
# | norm_grads_policy   | 5.63     |
# | norm_grads_q        | 69.7     |
# | total_timesteps     | 118000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0674   |
# | avg_norm_g          | 3.17     |
# | avg_norm_grads_f    | 3.09     |
# | avg_norm_k          | 2.54     |
# | avg_norm_k_dot_g    | 3.42     |
# | entropy             | 14.6     |
# | explained_variance  | 0.108    |
# | fps                 | 382      |
# | loss                | 1.47     |
# | loss_bc             | -0       |
# | loss_f              | 0.673    |
# | loss_policy         | 0.673    |
# | loss_q              | 1.9      |
# | mean_episode_length | 528      |
# | mean_episode_reward | 76.4     |
# | norm_grads          | 13       |
# | norm_grads_policy   | 3.39     |
# | norm_grads_q        | 12.5     |
# | total_timesteps     | 120000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.321    |
# | avg_norm_g          | 3.22     |
# | avg_norm_grads_f    | 2.97     |
# | avg_norm_k          | 1.85     |
# | avg_norm_k_dot_g    | 3.24     |
# | entropy             | 12.9     |
# | explained_variance  | -0.0652  |
# | fps                 | 380      |
# | loss                | 1.41     |
# | loss_bc             | -0       |
# | loss_f              | 0.121    |
# | loss_policy         | 0.121    |
# | loss_q              | 2.83     |
# | mean_episode_length | 541      |
# | mean_episode_reward | 70.7     |
# | norm_grads          | 10.9     |
# | norm_grads_policy   | 8.03     |
# | norm_grads_q        | 7.41     |
# | total_timesteps     | 122000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.277    |
# | avg_norm_g          | 67.1     |
# | avg_norm_grads_f    | 66.9     |
# | avg_norm_k          | 1.58     |
# | avg_norm_k_dot_g    | 39.9     |
# | entropy             | 4.52     |
# | explained_variance  | 0.685    |
# | fps                 | 380      |
# | loss                | 333      |
# | loss_bc             | -0       |
# | loss_f              | 10.6     |
# | loss_policy         | 10.6     |
# | loss_q              | 646      |
# | mean_episode_length | 538      |
# | mean_episode_reward | 62.2     |
# | norm_grads          | 152      |
# | norm_grads_policy   | 78       |
# | norm_grads_q        | 130      |
# | total_timesteps     | 124000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 7.34     |
# | avg_norm_grads_f    | 7.34     |
# | avg_norm_k          | 1.89     |
# | avg_norm_k_dot_g    | 6.98     |
# | entropy             | 17.3     |
# | explained_variance  | 0.404    |
# | fps                 | 378      |
# | loss                | 6.84     |
# | loss_bc             | -0       |
# | loss_f              | 2.15     |
# | loss_policy         | 2.15     |
# | loss_q              | 9.74     |
# | mean_episode_length | 542      |
# | mean_episode_reward | 67.1     |
# | norm_grads          | 59.9     |
# | norm_grads_policy   | 10.5     |
# | norm_grads_q        | 59       |
# | total_timesteps     | 126000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 10.3     |
# | avg_norm_grads_f    | 10.3     |
# | avg_norm_k          | 1.78     |
# | avg_norm_k_dot_g    | 9.7      |
# | entropy             | 1.33     |
# | explained_variance  | 0.317    |
# | fps                 | 376      |
# | loss                | 9.03     |
# | loss_bc             | -0       |
# | loss_f              | 2        |
# | loss_policy         | 2        |
# | loss_q              | 14.1     |
# | mean_episode_length | 549      |
# | mean_episode_reward | 72.7     |
# | norm_grads          | 38.8     |
# | norm_grads_policy   | 20.4     |
# | norm_grads_q        | 33       |
# | total_timesteps     | 128000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.531    |
# | avg_norm_g          | 3.16     |
# | avg_norm_grads_f    | 2.81     |
# | avg_norm_k          | 2.11     |
# | avg_norm_k_dot_g    | 3.31     |
# ...
# | entropy             | 1.5      |
# | explained_variance  | 0.233    |
# | fps                 | 358      |
# | loss                | 8.58     |
# | loss_bc             | -0       |
# | loss_f              | 0.476    |
# | loss_policy         | 0.476    |
# | loss_q              | 16.2     |
# | mean_episode_length | 695      |
# | mean_episode_reward | 87.4     |
# | norm_grads          | 40.9     |
# | norm_grads_policy   | 3.16     |
# | norm_grads_q        | 40.8     |
# | total_timesteps     | 156000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0513   |
# | avg_norm_g          | 4.76     |
# | avg_norm_grads_f    | 4.72     |
# | avg_norm_k          | 1.92     |
# | avg_norm_k_dot_g    | 4.54     |
# | entropy             | 14.6     |
# | explained_variance  | 0.748    |
# | fps                 | 358      |
# | loss                | 1.74     |
# | loss_bc             | -0       |
# | loss_f              | 0.966    |
# | loss_policy         | 0.966    |
# | loss_q              | 1.83     |
# | mean_episode_length | 681      |
# | mean_episode_reward | 98.6     |
# | norm_grads          | 23       |
# | norm_grads_policy   | 6.81     |
# | norm_grads_q        | 22       |
# | total_timesteps     | 158000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0816   |
# | avg_norm_g          | 1.25     |
# | avg_norm_grads_f    | 1.2      |
# | avg_norm_k          | 1.91     |
# | avg_norm_k_dot_g    | 1.23     |
# | entropy             | 15.8     |
# | explained_variance  | 0.871    |
# | fps                 | 357      |
# | loss                | -0.102   |
# | loss_bc             | -0       |
# | loss_f              | -0.0651  |
# | loss_policy         | -0.0651  |
# | loss_q              | 0.244    |
# | mean_episode_length | 704      |
# | mean_episode_reward | 100      |
# | norm_grads          | 3.62     |
# | norm_grads_policy   | 3.33     |
# | norm_grads_q        | 1.43     |
# | total_timesteps     | 160000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 2.1      |
# | avg_norm_grads_f    | 2.1      |
# | avg_norm_k          | 1.66     |
# | avg_norm_k_dot_g    | 2.17     |
# | entropy             | 14       |
# | explained_variance  | 0.211    |
# | fps                 | 357      |
# | loss                | 1.06     |
# | loss_bc             | -0       |
# | loss_f              | 0.64     |
# | loss_policy         | 0.64     |
# | loss_q              | 1.12     |
# | mean_episode_length | 707      |
# | mean_episode_reward | 115      |
# | norm_grads          | 11.5     |
# | norm_grads_policy   | 4.92     |
# | norm_grads_q        | 10.3     |
# | total_timesteps     | 162000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.39     |
# | avg_norm_g          | 3.65     |
# | avg_norm_grads_f    | 3.4      |
# | avg_norm_k          | 1.95     |
# | avg_norm_k_dot_g    | 3.6      |
# | entropy             | 16.7     |
# | explained_variance  | 0.807    |
# | fps                 | 356      |
# | loss                | 0.182    |
# | loss_bc             | -0       |
# | loss_f              | -0.213   |
# | loss_policy         | -0.213   |
# | loss_q              | 1.13     |
# | mean_episode_length | 708      |
# | mean_episode_reward | 128      |
# | norm_grads          | 13.5     |
# | norm_grads_policy   | 4.81     |
# | norm_grads_q        | 12.7     |
# | total_timesteps     | 164000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.13     |
# | avg_norm_g          | 7.5      |
# | avg_norm_grads_f    | 6.78     |
# | avg_norm_k          | 1.88     |
# | avg_norm_k_dot_g    | 7.49     |
# | entropy             | 10.8     |
# | explained_variance  | -0.127   |
# | fps                 | 357      |
# | loss                | 3.26     |
# | loss_bc             | -0       |
# | loss_f              | -0.433   |
# | loss_policy         | -0.433   |
# | loss_q              | 7.61     |
# | mean_episode_length | 669      |
# | mean_episode_reward | 143      |
# | norm_grads          | 46.7     |
# | norm_grads_policy   | 7.15     |
# | norm_grads_q        | 46.2     |
# | total_timesteps     | 166000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.55     |
# | avg_norm_g          | 6.16     |
# | avg_norm_grads_f    | 5.34     |
# | avg_norm_k          | 1.69     |
# | avg_norm_k_dot_g    | 5.11     |
# | entropy             | 11.3     |
# | explained_variance  | 0.441    |
# | fps                 | 356      |
# | loss                | 0.356    |
# | loss_bc             | -0       |
# | loss_f              | -1.28    |
# | loss_policy         | -1.28    |
# | loss_q              | 3.49     |
# | mean_episode_length | 680      |
# | mean_episode_reward | 144      |
# | norm_grads          | 49.5     |
# | norm_grads_policy   | 13.2     |
# | norm_grads_q        | 47.7     |
# | total_timesteps     | 168000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 80.8     |
# | avg_norm_grads_f    | 80.8     |
# | avg_norm_k          | 1.94     |
# | avg_norm_k_dot_g    | 75.2     |
# | entropy             | 15.7     |
# | explained_variance  | 0.0701   |
# | fps                 | 356      |
# | loss                | 96.1     |
# | loss_bc             | -0       |
# | loss_f              | 16       |
# | loss_policy         | 16       |
# | loss_q              | 161      |
# | mean_episode_length | 652      |
# | mean_episode_reward | 155      |
# | norm_grads          | 199      |
# | norm_grads_policy   | 83.6     |
# | norm_grads_q        | 180      |
# | total_timesteps     | 170000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 22.4     |
# | avg_norm_grads_f    | 22.4     |
# | avg_norm_k          | 2.01     |
# | avg_norm_k_dot_g    | 21.8     |
# | entropy             | 6.74     |
# | explained_variance  | 0.389    |
# | fps                 | 356      |
# | loss                | 40.6     |
# | loss_bc             | -0       |
# | loss_f              | 4.37     |
# | loss_policy         | 4.37     |
# | loss_q              | 72.6     |
# | mean_episode_length | 642      |
# | mean_episode_reward | 161      |
# | norm_grads          | 93.6     |
# | norm_grads_policy   | 37       |
# | norm_grads_q        | 86       |
# | total_timesteps     | 172000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 5.61     |
# | avg_norm_g          | 12.9     |
# | avg_norm_grads_f    | 9.44     |
# | avg_norm_k          | 1.46     |
# | avg_norm_k_dot_g    | 12.9     |
# | entropy             | 9.37     |
# | explained_variance  | 0.727    |
# | fps                 | 356      |
# | loss                | 30       |
# | loss_bc             | -0       |
# | loss_f              | -2.41    |
# | loss_policy         | -2.41    |
# | loss_q              | 65       |
# | mean_episode_length | 617      |
# | mean_episode_reward | 175      |
# | norm_grads          | 71.7     |
# | norm_grads_policy   | 13.1     |
# | norm_grads_q        | 70.5     |
# | total_timesteps     | 174000   |
# ----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0         |
# | avg_norm_g          | 0.421     |
# | avg_norm_grads_f    | 0.421     |
# | avg_norm_k          | 1.45      |
# | avg_norm_k_dot_g    | 0.421     |
# | entropy             | 0.00987   |
# | explained_variance  | 0.911     |
# | fps                 | 356       |
# | loss                | 0.0518    |
# | loss_bc             | -0        |
# | loss_f              | -1.38e-05 |
# | loss_policy         | -1.38e-05 |
# | loss_q              | 0.104     |
# | mean_episode_length | 552       |
# | mean_episode_reward | 178       |
# | norm_grads          | 6.54      |
# | norm_grads_policy   | 0.000361  |
# | norm_grads_q        | 6.54      |
# | total_timesteps     | 176000    |
# -----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0642   |
# | avg_norm_g          | 0.703    |
# | avg_norm_grads_f    | 0.641    |
# | avg_norm_k          | 1.9      |
# | avg_norm_k_dot_g    | 0.766    |
# | entropy             | 13.8     |
# | explained_variance  | 0.0847   |
# | fps                 | 356      |
# | loss                | -0.295   |
# | loss_bc             | -0       |
# | loss_f              | -0.199   |
# | loss_policy         | -0.199   |
# | loss_q              | 0.0852   |
# | mean_episode_length | 549      |
# | mean_episode_reward | 176      |
# | norm_grads          | 3.01     |
# | norm_grads_policy   | 2.1      |
# | norm_grads_q        | 2.16     |
# | total_timesteps     | 178000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0159   |
# | avg_norm_g          | 0.74     |
# | avg_norm_grads_f    | 0.726    |
# | avg_norm_k          | 1.91     |
# | avg_norm_k_dot_g    | 0.745    |
# | entropy             | 13.7     |
# | explained_variance  | 0.00242  |
# | fps                 | 356      |
# | loss                | -0.111   |
# | loss_bc             | -0       |
# | loss_f              | -0.0243  |
# | loss_policy         | -0.0243  |
# | loss_q              | 0.101    |
# | mean_episode_length | 574      |
# | mean_episode_reward | 171      |
# | norm_grads          | 1.94     |
# | norm_grads_policy   | 1.85     |
# | norm_grads_q        | 0.57     |
# | total_timesteps     | 180000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.423    |
# | avg_norm_g          | 1.87     |
# | avg_norm_grads_f    | 1.57     |
# | avg_norm_k          | 1.7      |
# | avg_norm_k_dot_g    | 1.98     |
# | entropy             | 9.45     |
# | explained_variance  | 0.0734   |
# | fps                 | 355      |
# | loss                | -0.327   |
# | loss_bc             | -0       |
# | loss_f              | -0.448   |
# | loss_policy         | -0.448   |
# | loss_q              | 0.431    |
# | mean_episode_length | 575      |
# | mean_episode_reward | 169      |
# | norm_grads          | 6.13     |
# | norm_grads_policy   | 1.79     |
# | norm_grads_q        | 5.86     |
# | total_timesteps     | 182000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.52     |
# | avg_norm_g          | 5.91     |
# | avg_norm_grads_f    | 4.92     |
# | avg_norm_k          | 1.85     |
# | avg_norm_k_dot_g    | 6.11     |
# | entropy             | 4.57     |
# | explained_variance  | 0.985    |
# | fps                 | 354      |
# | loss                | 2.67     |
# | loss_bc             | -0       |
# | loss_f              | -0.754   |
# | loss_policy         | -0.754   |
# | loss_q              | 6.95     |
# | mean_episode_length | 561      |
# | mean_episode_reward | 172      |
# | norm_grads          | 63.4     |
# | norm_grads_policy   | 2.34     |
# | norm_grads_q        | 63.4     |
# | total_timesteps     | 184000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0124   |
# | avg_norm_g          | 9        |
# | avg_norm_grads_f    | 8.99     |
# | avg_norm_k          | 1.95     |
# | avg_norm_k_dot_g    | 8.75     |
# | entropy             | 12.9     |
# | explained_variance  | 0.339    |
# | fps                 | 353      |
# | loss                | 5.51     |
# | loss_bc             | -0       |
# | loss_f              | 1.71     |
# | loss_policy         | 1.71     |
# | loss_q              | 7.86     |
# | mean_episode_length | 554      |
# | mean_episode_reward | 167      |
# | norm_grads          | 39.7     |
# | norm_grads_policy   | 18       |
# | norm_grads_q        | 35.4     |
# | total_timesteps     | 186000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.403    |
# | avg_norm_g          | 2.4      |
# | avg_norm_grads_f    | 2.16     |
# | avg_norm_k          | 1.97     |
# | avg_norm_k_dot_g    | 2.38     |
# | entropy             | 16.9     |
# | explained_variance  | 0.897    |
# | fps                 | 353      |
# | loss                | -0.564   |
# | loss_bc             | -0       |
# | loss_f              | -0.573   |
# | loss_policy         | -0.573   |
# | loss_q              | 0.354    |
# | mean_episode_length | 555      |
# | mean_episode_reward | 164      |
# | norm_grads          | 9.27     |
# | norm_grads_policy   | 1.75     |
# | norm_grads_q        | 9.1      |
# | total_timesteps     | 188000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 67.6     |
# | avg_norm_grads_f    | 67.6     |
# | avg_norm_k          | 1.77     |
# | avg_norm_k_dot_g    | 67.3     |
# | entropy             | 12.8     |
# | explained_variance  | 0.161    |
# | fps                 | 353      |
# | loss                | 845      |
# | loss_bc             | -0       |
# | loss_f              | 10.2     |
# | loss_policy         | 10.2     |
# | loss_q              | 1.67e+03 |
# | mean_episode_length | 526      |
# | mean_episode_reward | 169      |
# | norm_grads          | 346      |
# | norm_grads_policy   | 113      |
# | norm_grads_q        | 327      |
# | total_timesteps     | 190000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.397    |
# | avg_norm_g          | 2.79     |
# | avg_norm_grads_f    | 2.58     |
# | avg_norm_k          | 1.94     |
# | avg_norm_k_dot_g    | 2.7      |
# | entropy             | 12.6     |
# | explained_variance  | 0.647    |
# | fps                 | 353      |
# | loss                | 0.197    |
# | loss_bc             | -0       |
# | loss_f              | 0.0528   |
# | loss_policy         | 0.0528   |
# | loss_q              | 0.54     |
# | mean_episode_length | 505      |
# | mean_episode_reward | 174      |
# | norm_grads          | 3.29     |
# | norm_grads_policy   | 2.2      |
# | norm_grads_q        | 2.46     |
# | total_timesteps     | 192000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.45     |
# | avg_norm_grads_f    | 4.45     |
# | avg_norm_k          | 1.71     |
# | avg_norm_k_dot_g    | 4.32     |
# | entropy             | 10.7     |
# | explained_variance  | -0.128   |
# | fps                 | 353      |
# | loss                | 2.9      |
# | loss_bc             | -0       |
# | loss_f              | 1.2      |
# | loss_policy         | 1.2      |
# | loss_q              | 3.62     |
# | mean_episode_length | 489      |
# | mean_episode_reward | 174      |
# | norm_grads          | 19.8     |
# | norm_grads_policy   | 3.86     |
# | norm_grads_q        | 19.4     |
# | total_timesteps     | 194000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0247   |
# | avg_norm_g          | 5.29     |
# | avg_norm_grads_f    | 5.27     |
# | avg_norm_k          | 1.53     |
# | avg_norm_k_dot_g    | 5.33     |
# | entropy             | 5.88     |
# | explained_variance  | 0.855    |
# | fps                 | 354      |
# | loss                | 6.22     |
# | loss_bc             | -0       |
# | loss_f              | 1.01     |
# | loss_policy         | 1.01     |
# | loss_q              | 10.5     |
# | mean_episode_length | 514      |
# | mean_episode_reward | 174      |
# | norm_grads          | 23.8     |
# | norm_grads_policy   | 11.5     |
# | norm_grads_q        | 20.8     |
# | total_timesteps     | 196000   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.629    |
# | avg_norm_g          | 3.3      |
# | avg_norm_grads_f    | 2.92     |
# | avg_norm_k          | 2.01     |
# | avg_norm_k_dot_g    | 3.3      |
# | entropy             | 16.1     |
# | explained_variance  | 0.956    |
# | fps                 | 354      |
# | loss                | -0.709   |
# | loss_bc             | -0       |
# | loss_f              | -0.696   |
# | loss_policy         | -0.696   |
# | loss_q              | 0.296    |
# | mean_episode_length | 481      |
# | mean_episode_reward | 177      |
# | norm_grads          | 11.7     |
# | norm_grads_policy   | 6.75     |
# | norm_grads_q        | 9.55     |
# | total_timesteps     | 198000   |
# ----------------------------------

# %%
# Record & show video 
record_video('LunarLander-v2', model, video_length=1500, prefix='LunarLander-v2-200000')
show_videos('videos', prefix='LunarLander-v2-200000')
# Random Agent, after training
mean_reward_after_train = evaluate(model, num_steps=10000)
# Out:
# Saving video to  /content/videos/LunarLander-v2-200000-step-0-to-step-1500.mp4
# <video alt="videos/LunarLander-v2-200000-step-0-to-step-1500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
# Mean reward: 181.2 Num episodes: 24
